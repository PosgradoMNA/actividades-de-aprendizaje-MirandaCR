# %% [markdown]
# # Data Analysis with Python
#
# ## Module 1 - Introduction

# %% [markdown]
# #### **Introduction to Data Analysis with Python**
# We learn if is possible to estimate the price of used car based on its characteristics.

# %% [markdown]
# #### **The problem**
# DataScience/data analysis helps to answer questions from data.
#
# Data Analysis role is:
# - Discovering information
# - Answering questions
# - Predicting future
#
# In this particular case of car prices, we are going to answer the question: how much money should be a car sell for?
#
# In order to determinate the best price we can answer more question like:
# - Is there data on the prices of other cars and their characteristics?
# - What features of cars affect their prices?, Colour?, Brand?
# - Does horsepower also affect the selling price, or perhaps, something else?

# %% [markdown]
# #### **Understanding the Data**
#
# Loading the data

# %%
import pandas as pd
import numpy as np

# %%
# Car atribbutes 

names_auto = ["symboling",
 "normalized_losses",
 "make",
 "fuel_type",
 "aspiration",
 "doors",
 "body_style",
 "drive_wheels",
 "engine_location",
 "wheel_base",
 "length",
 "width",
 "height",
 "curb_weigth",
 "engine_type",
 "cylinders",
 "engine_size",
 "fuel_system",
 "bore",
 "stroke",
 "compression_ratio",
 "horsepower",
 "peak_rpm",
 "city_mpg",
 "highwway_mpg",
 "price"
 ]

# %%
autos = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", names=names_auto)
autos.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration doors  \
# 0          3                 ?  alfa-romero       gas        std   two
# 1          3                 ?  alfa-romero       gas        std   two
# 2          1                 ?  alfa-romero       gas        std   two
# 3          2               164         audi       gas        std  four
# 4          2               164         audi       gas        std  four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# ...

# %% [markdown]
# #### **Python Packages for Data Science**

# %%
# Scientifics computing libraries
import pandas as pd   #-- datastructures & tools
import numpy as np    #-- arrays and matrices
import scipy          #-- integrals, optimization, differential equations
  

# Visualization libraries
import matplotlib.pyplot as plt  #-- most popular for plots & graphs
import seaborn as sns            #-- plots


# ML algorithm libraries
import sklearn         #-- machine learning: regression, classifications, etc
import statsmodels     #-- to explore data, estimate models and permform statistical tests

# %% [markdown]
# #### **Importing and Exporting Data in Python**
#
# Importing: Process of loading and reading data. We must to consider 2 important propieties:
# - Format (.csv,.xlsx,.json,etc)
# - File path (computer, internet)

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data", names=names_auto)
df.head() # first rows of df
#df.tail() #last rows
# Out:
#    symboling normalized_losses         make fuel_type aspiration doors  \
# 0          3                 ?  alfa-romero       gas        std   two
# 1          3                 ?  alfa-romero       gas        std   two
# 2          1                 ?  alfa-romero       gas        std   two
# 3          2               164         audi       gas        std  four
# 4          2               164         audi       gas        std  four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# ...

# %%
# import / export

# df.read_excel() / df.to_excel()
# df.read_sql() / df.to_sql()
# df.read_csv() / df.to_csv()

# %% [markdown]
# #### **Getting Started Analyzing Data in Python**
#
# Understanding data before analysis
#
# We need to check data types for detecting pontential incorrect assigment data. The data types is:
#
# Pandas type ---> Native Python
# Object --> string
# int64  --> int
# float64 --> float
# datetime64,timedelta[ns] --> datetime

# %%
# checking datetupes
df.dtypes
# Out:
# symboling              int64
# normalized_losses     object
# make                  object
# fuel_type             object
# aspiration            object
# doors                 object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weigth            int64
# engine_type           object
# cylinders             object
# engine_size            int64
# fuel_system           object
# bore                  object
# stroke                object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highwway_mpg           int64
# price                 object
# dtype: object

# %%
# statistical summary
df.describe()
# Out:
#         symboling  wheel_base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb_weigth  engine_size  compression_ratio    city_mpg  highwway_mpg
# count   205.000000   205.000000         205.000000  205.000000    205.000000
# mean   2555.565854   126.907317          10.142537   25.219512     30.751220
# std     520.680204    41.642693           3.972040    6.542142      6.886443
# ...

# %%
# including full summary
df.describe(include="all")
# Out:
#          symboling normalized_losses    make fuel_type aspiration doors  \
# count   205.000000               205     205       205        205   205
# unique         NaN                52      22         2          2     3
# top            NaN                 ?  toyota       gas        std  four
# freq           NaN                41      32       185        168   114
# mean      0.834146               NaN     NaN       NaN        NaN   NaN
# std       1.245307               NaN     NaN       NaN        NaN   NaN
# min      -2.000000               NaN     NaN       NaN        NaN   NaN
# 25%       0.000000               NaN     NaN       NaN        NaN   NaN
# 50%       1.000000               NaN     NaN       NaN        NaN   NaN
# 75%       2.000000               NaN     NaN       NaN        NaN   NaN
# max       3.000000               NaN     NaN       NaN        NaN   NaN
#
#        body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
# summaru od dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   doors              205 non-null    object
#  6   body_style         205 non-null    object
#  7   drive_wheels       205 non-null    object
#  8   engine_location    205 non-null    object
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weigth        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  cylinders          205 non-null    object
# ...
