# %% [markdown]
# ## Condition
# ```
# # Tiene formato de código
# ```

# %%
a = 6

# Equal
a == 7
# Out:
# False

# %%
i = 6
i >= 5
# Out:
# True

# %%
i < 6
# Out:
# False

# %%
# Not equal
i!=6
# Out:
# False

# %%
"AC/DC" == "Michael Jackson"
"AC/DC" != "Michael Jackson"
# Out:
# True

# %% [markdown]
# ## Branching
#
# Is used to run different statement for a different input

# %%
age = 19

# IF
if(age > 18):
  print("you can enter")
print("move on")
# Out:
# you can enter
# move on

# %%
# IF ELSE

age = 17

if(age > 18):
  print("you can enter")
else:
  print("go see Meat Loaf")
print("move on")
# Out:
# go see Meat Loaf
# move on

# %%
# ELIF

age = 18

if(age > 18):
  print("you can enter")
elif(age == 18):
  print("go see Pink Floyd")
else:
  print("go see Meat Loaf")
print("move on")
# Out:
# go see Pink Floyd
# move on

# %% [markdown]
# ## Logic operators

# %%
# negation
not(True)
# Out:
# False

# %%
# or
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
album_year = 1990

if (album_year < 1980) or (album_year > 1989):
  print("The Album was made in the 70's or 90's")
else:
  print("The Album was made in the 80's")
# Out:
# The Album was made in the 70's or 90's

# %%
# and
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
album_year = 1983

if (album_year < 1990) and (album_year > 1979):
  print("The Album was made in the 80's")
else:
  print("The Album was made in the 70's or 90's")
# Out:
# The Album was made in the 80's

# %% [markdown]
# ## Loops

# %%
range(3)
# Out:
# range(0, 3)

# %%
range(10,15)
# Out:
# range(10, 15)

# %%
squares = ["red","yellow","green","purple","blue"]

for i in range(0,5):
  squares[i] = "white"

squares
# Out:
# ['white', 'white', 'white', 'white', 'white']

# %%
squares = ["red","yellow","green"]

for square in squares:
  print(square)
# Out:
# red
# yellow
# green

# %%
for i, square in enumerate(squares):
  print(square,i)
# Out:
# red 0
# yellow 1
# green 2

# %% [markdown]
# ## While

# %%
squares = ["orange","orange","purple","blue"]
Newsquares = []

i=0

while(squares[i]=="orange"):
  Newsquares.append(squares[i])
  i=i+1
Newsquares
# Out:
# ['orange', 'orange']

# %% [markdown]
# ## FUNCTIONS
#
# Take some input then produce some output or change

# %%
def add(a,n):
  '''add n to a'''
  b = a + n

  print(a,"+",n,"=",b)
  return b

# %%
album_ratings = [10,8.5,9.5,7,9.5,9,9.5]

L = len(album_ratings)
S = sum(album_ratings)

print(L,"-",S)
# Out:
# 7 - 63.0

# %%
# sort
sorted(album_ratings)
# Out:
# [7, 8.5, 9, 9.5, 9.5, 9.5, 10]

# %%
album_ratings.sort()
album_ratings
# Out:
# [7, 8.5, 9, 9.5, 9.5, 9.5, 10]

# %%
# using functions
add(2,3)
# Out:
# 2 + 3 = 5
# 5

# %%
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a, n)
#     add n to a

# %%
# Pass - performs no task
def NoWork():
  pass

NoWork()

# %%
def printStuff(Stuff):
  for i, s in enumerate(Stuff):
    print("Album",i,"Rating is",s)

album_ratings = [10,8.5,9.5]
printStuff(album_ratings)
# Out:
# Album 0 Rating is 10
# Album 1 Rating is 8.5
# Album 2 Rating is 9.5

# %%
# Collecting arguments

def ArtistNames(*names):
  for name in names:
    print(name)

ArtistNames("MJ","AC/DC")
# Out:
# MJ
# AC/DC

# %%
# Scope

# Local Variable
def Thriller():
  Date = 1982
  return(Date)

Date = 2017

print(Thriller())
print(Date)
# Out:
# 1982
# 2017

# %%
# Global

def PinkFloyd():
  global ClaimedSales
  ClaimedSales = "45 million"
  return ClaimedSales

# %% [markdown]
# ## Objects
# An object is an instance of a particular type that has a type, internal representation, methods

# %%
print(type(1))
print(type([1,2]))
print(type({"A":1,"B":2}))
# Out:
# <class 'int'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# ## Methods
# Functions that every instance of that class or type provides

# %%
# Example
r = [2,3,1,5,6,2]
r.reverse()
r
# Out:
# [2, 6, 5, 1, 3, 2]

# %% [markdown]
# ## Class

# %%
#Define atributes to initialize each instance of class

class Circle(object):
  def __init__(self,radius,color):
    self.radius=radius;
    self.color=color;

RedCircle = Circle(10,"red")
RedCircle.radius
# Out:
# 10

# %% [markdown]
# ## Method
# Functions that interact and change

# %%
class Circle(object):
  def __init__(self,radius,color):
    self.radius=radius;
    self.color=color;

  def add_radius(self,r):
    self.radius = self.radius + r


RedCircle = Circle(2,"red")
RedCircle.add_radius(8)
RedCircle.radius
# Out:
# 10

# %%
# Attributes of object
dir(Circle)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_radius']
